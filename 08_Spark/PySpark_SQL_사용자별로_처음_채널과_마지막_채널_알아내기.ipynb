# %%
# !pip install pyspark==3.5.3
# Out:
# Collecting pyspark==3.5.3
#   Downloading pyspark-3.5.3.tar.gz (317.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 MB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.12/dist-packages (from pyspark==3.5.3) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.3-py2.py3-none-any.whl size=317840629 sha256=54529f37ef8d8c6086aaf3ad8af391150276abd1004429a1528e199cb4d4fefb
#   Stored in directory: /root/.cache/pip/wheels/07/a0/a3/d24c94bf043ab5c7e38c30491199a2a11fef8d2584e6df7fb7
# Successfully built pyspark
# Installing collected packages: pyspark
#   Attempting uninstall: pyspark
#     Found existing installation: pyspark 3.5.1
#     Uninstalling pyspark-3.5.1:
#       Successfully uninstalled pyspark-3.5.1
# Successfully installed pyspark-3.5.3

# %%
# !cd /usr/local/lib/python3.12/dist-packages/pyspark/jars && wget https://s3.amazonaws.com/redshift-downloads/drivers/jdbc/2.1.0.30/redshift-jdbc42-2.1.0.30.jar
# Out:
# --2025-11-21 07:16:30--  https://s3.amazonaws.com/redshift-downloads/drivers/jdbc/2.1.0.30/redshift-jdbc42-2.1.0.30.jar
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 16.182.73.200, 52.217.122.224, 16.15.218.210, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|16.182.73.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1088404 (1.0M) [application/java-archive]
# Saving to: ‘redshift-jdbc42-2.1.0.30.jar’
#
# redshift-jdbc42-2.1 100%[===================>]   1.04M  --.-KB/s    in 0.09s
#
# 2025-11-21 07:16:30 (11.1 MB/s) - ‘redshift-jdbc42-2.1.0.30.jar’ saved [1088404/1088404]

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL #1") \
    .getOrCreate()

# %%
rows_test = [
    { 'value': 1, 'name': 'Luka' },
    { 'value': 2, 'name': 'Luka'},
    { 'value': 3, 'name': 'Dirk' },
    { 'value': 4, 'name': 'Dirk' },
    { 'value': 5, 'name': 'Luka' },
]

df = spark.createDataFrame(rows_test)

# %%
df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- value: long (nullable = true)

# %%
df.show()
# Out:
# +----+-----+
# |name|value|
# +----+-----+
# |Luka|    1|
# |Luka|    2|
# |Dirk|    3|
# |Dirk|    4|
# |Luka|    5|
# +----+-----+

# %%
df.createOrReplaceTempView("rows_test")

# %%
spark.sql("""
  SELECT
    value,
    SUM(value) OVER (
        order by value
        rows between 2 preceding and 2 following
    ) AS rolling_sum
  FROM rows_test""").show()
# Out:
# +-----+-----------+
# |value|rolling_sum|
# +-----+-----------+
# |    1|          6|
# |    2|         10|
# |    3|         15|
# |    4|         14|
# |    5|         12|
# +-----+-----------+

# %%
spark.sql("""
  SELECT
    value,
    SUM(value) OVER (
        order by value
        rows between unbounded preceding and 2 following
    ) AS rolling_sum
  FROM rows_test""").show()
# Out:
# +-----+-----------+
# |value|rolling_sum|
# +-----+-----------+
# |    1|          6|
# |    2|         10|
# |    3|         15|
# |    4|         15|
# |    5|         15|
# +-----+-----------+

# %%
spark.sql("""
  SELECT
    *,
    FIRST_VALUE(value) OVER (
        partition by name
        order by value
        rows between unbounded preceding and unbounded following
    ) AS min_value,
    LAST_VALUE(value) OVER (
        partition by name
        order by value
        rows between unbounded preceding and unbounded following
    ) AS max_value
  FROM rows_test""").show()
# Out:
# +----+-----+---------+---------+
# |name|value|min_value|max_value|
# +----+-----+---------+---------+
# |Dirk|    3|        3|        4|
# |Dirk|    4|        3|        4|
# |Luka|    1|        1|        5|
# |Luka|    2|        1|        5|
# |Luka|    5|        1|        5|
# +----+-----+---------+---------+

# %% [markdown]
# ## Redshift 상의 다음 테이블을 데이터프레임으로 로딩하기
# user_session_channel, session_timestamp, session_transaction

# %%
# Redshift와 연결해서 DataFrame으로 로딩하기
url = "jdbc:redshift://learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev?user=your-username&password=your-password"

df_user_session_channel = spark.read \
    .format("jdbc") \
    .option("driver", "com.amazon.redshift.Driver") \
    .option("url", url) \
    .option("dbtable", "raw_data.user_session_channel") \
    .load()

df_session_timestamp = spark.read \
    .format("jdbc") \
    .option("driver", "com.amazon.redshift.Driver") \
    .option("url", url) \
    .option("dbtable", "raw_data.session_timestamp") \
    .load()

df_session_transaction = spark.read \
    .format("jdbc") \
    .option("driver", "com.amazon.redshift.Driver") \
    .option("url", url) \
    .option("dbtable", "raw_data.session_transaction") \
    .load()

# %%
df_user_session_channel.createOrReplaceTempView("user_session_channel")
df_session_timestamp.createOrReplaceTempView("session_timestamp")
df_session_transaction.createOrReplaceTempView("session_transaction")

# %%
df_user_session_channel.show(5)
# Out:
# +------+--------------------+---------+
# |userid|           sessionid|  channel|
# +------+--------------------+---------+
# |  1651|0004289ee1c7b8b08...|  Organic|
# |  1197|00053f5e11d1fe4e4...| Facebook|
# |  1401|00056c20eb5a02958...| Facebook|
# |  1399|00063cb5da1826feb...| Facebook|
# |  1667|000958fdaefe0dd06...|Instagram|
# +------+--------------------+---------+
# only showing top 5 rows

# %%
df_session_timestamp.show(5)
# Out:
# +--------------------+--------------------+
# |           sessionid|                  ts|
# +--------------------+--------------------+
# |00029153d12ae1c9a...|2019-10-18 14:14:...|
# |0004289ee1c7b8b08...|2019-11-16 21:20:...|
# |0006246bee639c7a7...|2019-08-10 16:33:...|
# |0006dd05ea1e999dd...|2019-07-06 19:54:...|
# |000958fdaefe0dd06...|2019-11-02 14:52:...|
# +--------------------+--------------------+
# only showing top 5 rows

# %%
df_session_transaction.show(5)
# Out:
# +--------------------+--------+------+
# |           sessionid|refunded|amount|
# +--------------------+--------+------+
# |00029153d12ae1c9a...|   false|    85|
# |008909bd27b680698...|   false|    13|
# |0107acb41ef20db22...|   false|    16|
# |018544a2c48077d2c...|   false|    39|
# |020c38173caff0203...|   false|    61|
# +--------------------+--------+------+
# only showing top 5 rows

# %% [markdown]
# ## 위의 테이블들을 이용해서 사용자별로 처음 채널과 마지막 채널 알아내기

# %%
first_last_channel_df = spark.sql("""
WITH RECORD AS (
  SELECT /*사용자의 유입에 따른, 채널 순서 매기는 쿼리*/
      userid,
      channel,
      ROW_NUMBER() OVER (PARTITION BY userid ORDER BY ts ASC) AS seq_first,
      ROW_NUMBER() OVER (PARTITION BY userid ORDER BY ts DESC) AS seq_last
  FROM user_session_channel u
  LEFT JOIN session_timestamp t
    ON u.sessionid = t.sessionid
)
SELECT /*유저의 첫번째 유입채널, 마지막 유입 채널 구하기*/
      f.userid,
      f.channel first_channel,
      l.channel last_channel
FROM RECORD f
INNER JOIN RECORD l ON f.userid = l.userid
WHERE f.seq_first = 1 and l.seq_last = 1
ORDER BY userid
""")

# %%
first_last_channel_df.show(10)
# Out:
# +------+-------------+------------+
# |userid|first_channel|last_channel|
# +------+-------------+------------+
# |    27|      Youtube|   Instagram|
# |    29|        Naver|       Naver|
# |    33|       Google|     Youtube|
# |    34|      Youtube|       Naver|
# |    36|        Naver|     Youtube|
# |    40|      Youtube|      Google|
# |    41|     Facebook|     Youtube|
# |    44|        Naver|   Instagram|
# |    45|      Youtube|   Instagram|
# |    59|    Instagram|   Instagram|
# +------+-------------+------------+
# only showing top 10 rows

# %%
first_last_channel_df2 = spark.sql("""
SELECT DISTINCT A.userid,
    FIRST_VALUE(A.channel) over(partition by A.userid order by B.ts
rows between unbounded preceding and unbounded following) AS First_Channel,
    LAST_VALUE(A.channel) over(partition by A.userid order by B.ts
rows between unbounded preceding and unbounded following) AS Last_Channel
FROM user_session_channel A
LEFT JOIN session_timestamp B
ON A.sessionid = B.sessionid""")

# %%
first_last_channel_df2.show()
# Out:
# +------+-------------+------------+
# |userid|First_Channel|Last_Channel|
# +------+-------------+------------+
# |    27|      Youtube|   Instagram|
# |    29|        Naver|       Naver|
# |    33|       Google|     Youtube|
# |    34|      Youtube|       Naver|
# |    36|        Naver|     Youtube|
# |    40|      Youtube|      Google|
# |    41|     Facebook|     Youtube|
# |    44|        Naver|   Instagram|
# |    45|      Youtube|   Instagram|
# |    59|    Instagram|   Instagram|
# |    64|      Youtube|     Youtube|
# |    65|      Youtube|     Organic|
# |    68|      Youtube|     Organic|
# |    69|     Facebook|   Instagram|
# |    80|      Organic|       Naver|
# |    84|       Google|     Youtube|
# |    87|      Youtube|      Google|
# |    97|      Organic|     Organic|
# |   112|     Facebook|     Youtube|
# |   113|      Organic|     Organic|
# +------+-------------+------------+
# only showing top 20 rows
