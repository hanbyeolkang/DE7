# %% [markdown]
# **환경 설정**

# %%
# !pip install ipython-sql==0.4.1
# !pip install SQLAlchemy==1.4.49

# %%
# %load_ext sql

# %%
# ID와 PW를 자신의 환경에 맞게 수정 - password
# %sql postgresql://strongstar1210:password@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev

# %% [markdown]
# # 숙제 1. 사용자별로 처음 채널과 마지막 채널 알아내기

# %%
# %%sql
#
# SELECT DISTINCT
#   usc.userid,
#   FIRST_VALUE(usc.channel) OVER(
#     PARTITION BY usc.userid
#     ORDER BY st.ts
#     ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING
#   ) AS first_channel,
#   LAST_VALUE(usc.channel) OVER(
#     PARTITION BY usc.userid
#     ORDER BY st.ts
#     ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING
#   ) AS last_channel
# FROM raw_data.user_session_channel usc
# JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# --WHERE usc.userid = 251
# LIMIT 100
# Out:
#  * postgresql://strongstar1210:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 100 rows affected.
# [(27, 'Youtube', 'Instagram'),
#  (29, 'Naver', 'Naver'),
#  (33, 'Google', 'Youtube'),
#  (40, 'Youtube', 'Google'),
#  (44, 'Naver', 'Instagram'),
#  (68, 'Youtube', 'Organic'),
#  (191, 'Naver', 'Instagram'),
#  (196, 'Facebook', 'Naver'),
#  (197, 'Naver', 'Youtube'),
#  (210, 'Google', 'Google'),
#  (225, 'Facebook', 'Naver'),
#  (229, 'Google', 'Facebook'),
#  (232, 'Instagram', 'Naver'),
#  (248, 'Naver', 'Instagram'),
#  (255, 'Facebook', 'Instagram'),
#  (265, 'Facebook', 'Instagram'),
#  (266, 'Google', 'Instagram'),
#  (267, 'Instagram', 'Naver'),
#  (277, 'Naver', 'Naver'),
#  (280, 'Google', 'Organic'),
#  (363, 'Naver', 'Facebook'),
#  (420, 'Youtube', 'Facebook'),
#  (465, 'Organic', 'Youtube'),
#  (468, 'Instagram', 'Facebook'),
#  (473, 'Youtube', 'Naver'),
#  (533, 'Instagram', 'Google'),
#  (538, 'Youtube', 'Organic'),
# ...

# %% [markdown]
# # 숙제 2. Gross Revenue가 가장 큰 UserID 10개 찾기

# %%
# %%sql
#
# WITH base AS (
#   SELECT usc.userid,
#     SUM(t.amount) AS gross_revenue,
#     RANK() OVER(ORDER BY gross_revenue DESC) AS rnk
#   FROM raw_data.user_session_channel AS usc
#   JOIN raw_data.session_transaction AS t ON usc.sessionid = t.sessionid
#   GROUP BY usc.userid
# )
# SELECT userid, gross_revenue, rnk
# FROM base
# WHERE rnk < 11
# ORDER BY rnk
# Out:
#  * postgresql://strongstar1210:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(989, 743, 1),
#  (772, 556, 2),
#  (1615, 506, 3),
#  (654, 488, 4),
#  (1651, 463, 5),
#  (973, 438, 6),
#  (262, 422, 7),
#  (1099, 421, 8),
#  (2682, 414, 9),
#  (891, 412, 10)]

# %% [markdown]
# # 숙제 3. raw_data.nps 테이블을 바탕으로 월별 NPS 계산

# %%
# %%sql
#
# SELECT
#   TO_CHAR(created_at, 'YYYY-MM') AS month,
#   ROUND(SUM(CASE WHEN score >= 9 THEN 1 WHEN score <= 6 THEN -1 END)*100.0/COUNT(1),2) AS nps
# FROM raw_data.nps
# GROUP BY month
# ORDER BY month DESC
# Out:
#  * postgresql://strongstar1210:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 12 rows affected.
# [('2019-12', Decimal('65.99')),
#  ('2019-11', Decimal('61.29')),
#  ('2019-10', Decimal('53.29')),
#  ('2019-09', Decimal('37.95')),
#  ('2019-08', Decimal('67.71')),
#  ('2019-07', Decimal('64.51')),
#  ('2019-06', Decimal('65.02')),
#  ('2019-05', Decimal('54.52')),
#  ('2019-04', Decimal('53.00')),
#  ('2019-03', Decimal('52.91')),
#  ('2019-02', Decimal('30.54')),
#  ('2019-01', Decimal('2.36'))]
